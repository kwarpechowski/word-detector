# %%
from nltk.corpus import names
from nltk.tokenize import word_tokenize
from nltk.corpus import names
import nltk;

# %%
import json

with open('result_person_org.json', encoding='utf-8') as data_file:
    data = json.loads(data_file.read())

# %%
featuresets = [(n, (m)) for (n, m) in data.items()]

# %%
train_set, test_set = featuresets[0:4], featuresets[:1500]

# %%
train_set
# Out:
# [('1', 'other'), ('7', 'other'), ('8', 'other'), ('9', 'other')]

# %%
def gender_features2(word):
    return {'test': word}

# %%
labeled_names = [(n, (m)) for (n, m) in data.items()]
import random
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features2(n), g) for (n,g) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
train_set
# Out:
# [({'test': 'Polonia'}, 'orgName'),
#  ({'test': 'Raja'}, 'persName'),
#  ({'test': 'WAT'}, 'orgName'),
#  ({'test': 'Marek Dobrzyński'}, 'persName'),
#  ({'test': 'łodzkich'}, 'other'),
#  ({'test': 'Nocznickiego'}, 'persName'),
#  ({'test': 'Irena Głowacka'}, 'persName'),
#  ({'test': 'ul. Saskiej'}, 'other'),
#  ({'test': 'ulicy Skaryszewskiej'}, 'other'),
#  ({'test': 'Pawłem'}, 'persName'),
#  ({'test': 'Kidawa'}, 'persName'),
#  ({'test': 'Grzegorz Hańderek'}, 'persName'),
#  ({'test': 'Miechowicach'}, 'other'),
#  ({'test': 'Andrzej Łukasiak'}, 'persName'),
#  ({'test': 'Marię Dul'}, 'persName'),
#  ({'test': 'Jordana'}, 'persName'),
#  ({'test': 'Raula Wallenberga'}, 'persName'),
#  ({'test': 'Salem'}, 'persName'),
#  ({'test': 'Zalewem Zegrzyńskim'}, 'other'),
#  ({'test': 'Piły'}, 'other'),
#  ({'test': 'Brandenburgię'}, 'other'),
#  ({'test': 'Godzina 14.12'}, 'other'),
#  ({'test': 'Konstancin-Jeziorna'}, 'other'),
#  ({'test': 'Adaś'}, 'persName'),
# ...

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features

# %%
classifier.classify(gender_features2('ABW'))
# Out:
# 'orgName'
